# %% [markdown]
# <a href="https://colab.research.google.com/github/aleks13082002/ActiveInference/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Active Inference in un UAV Simulato**
